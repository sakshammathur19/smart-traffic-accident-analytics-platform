# %%
(
    spark.table("gold_congestion_analysis")
    .coalesce(1)
    .write
    .mode("overwrite")
    .option("header", "true")
    .csv("s3://smart-traffic-analytics/export/congestion")
)

# %%
(
    spark.table("gold_accident_hotspots")
    .coalesce(1)
    .write
    .mode("overwrite")
    .option("header", "true")
    .csv("s3://smart-traffic-analytics/export/accidents")
)

# %%
(
    spark.table("gold_emergency_alerts")
    .coalesce(1)
    .write
    .mode("overwrite")
    .option("header", "true")
    .csv("s3://smart-traffic-analytics/export/emergency")
)
